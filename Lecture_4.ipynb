# %% [markdown]
# # Lecture 4 - Leontief Price Model
# Edgar Hertwich
#
# **Leontief Price Model**
# In the following you import a global IO table, aggregated to 17 sectors of a single global economy. The steps necessary to parse this data and convert it to IO variables (in numpy) are already conducted.
# We evaluate the following: what happens if all low-skilled workers receive a 50% raise? How much do prices of the different products increase? Which products are most affected? How much does the cost of household consumption increase?

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("IOweek4data.xlsx")
Zdf = df.iloc[0:17,3:20].set_index(df.iloc[0:17,0])
Ydf = df.iloc[0:17,21:27].set_index(df.iloc[0:17,0])
Vdf = df.iloc[18:25,3:20].set_index(df.iloc[18:25,1])
Fdf=df.iloc[40:43,3:20].set_index(pd.Series(['CO2','CH4','N2O']))
Vdf
# Out:
# C:\Users\edgarhe\Miniconda3\envs\pymr\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# C:\Users\edgarhe\Miniconda3\envs\pymr\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
#                                                     Agriculture, hunting, forestry & fishing  \
# Unnamed: 1
# Taxes less subsidies on products purchased: Total                               90944.026974
# Other net taxes on production                                                    5272.857687
# Compensation of employees; wages, salaries, & e...                              65917.876946
# Compensation of employees; wages, salaries, & e...                             118929.950011
# Compensation of employees; wages, salaries, & e...                             680930.106533
# Operating surplus: Consumption of fixed capital                                239386.450509
# Operating surplus: Remaining net operating surplus                             663587.979895
#
#                                                     Mining & quarrying  \
# Unnamed: 1
# Taxes less subsidies on products purchased: Total        157167.018426
# Other net taxes on production                            107941.813561
# Compensation of employees; wages, salaries, & e...       131816.833089
# Compensation of employees; wages, salaries, & e...        82646.453477
# Compensation of employees; wages, salaries, & e...       362757.092648
# Operating surplus: Consumption of fixed capital          381876.835192
# Operating surplus: Remaining net operating surplus       927731.089442
#
#                                                     Food production, beverages & tobacco  \
# Unnamed: 1
# Taxes less subsidies on products purchased: Total                          164173.754462
# Other net taxes on production                                                 -35.944341
# Compensation of employees; wages, salaries, & e...                         169326.870854
# Compensation of employees; wages, salaries, & e...                          45205.117871
# Compensation of employees; wages, salaries, & e...                         309375.933887
# Operating surplus: Consumption of fixed capital                            143132.420819
# Operating surplus: Remaining net operating surplus                         382131.698836
#
#                                                     Textiles, leather & wearing apparel  \
# Unnamed: 1
# Taxes less subsidies on products purchased: Total                          71663.168994
# Other net taxes on production                                              18458.717786
# Compensation of employees; wages, salaries, & e...                         69197.378191
# Compensation of employees; wages, salaries, & e...                         24918.887587
# Compensation of employees; wages, salaries, & e...                        194743.898914
# Operating surplus: Consumption of fixed capital                            62955.582120
# Operating surplus: Remaining net operating surplus                         89299.757401
#
#                                                     Wood, paper & publishing  \
# Unnamed: 1
# Taxes less subsidies on products purchased: Total               60438.043314
# Other net taxes on production                                   15295.316745
# Compensation of employees; wages, salaries, & e...             147160.772530
# Compensation of employees; wages, salaries, & e...              27420.276391
# Compensation of employees; wages, salaries, & e...             235948.058012
# Operating surplus: Consumption of fixed capital                 99926.013331
# Operating surplus: Remaining net operating surplus             179487.228738
#
#                                                     Petroleum, chemicals & non-metallic mineral products  \
# Unnamed: 1
# Taxes less subsidies on products purchased: Total                                       424756.382071
# Operating surplus: Consumption of fixed capital                                          6.394493e+05
# Operating surplus: Remaining net operating surplus                                       1.451684e+06
#
#                                                         Transport  \
# Unnamed: 1
# Taxes less subsidies on products purchased: Total   214237.557368
# Other net taxes on production                        79237.836093
# Compensation of employees; wages, salaries, & e...  403886.704140
# Compensation of employees; wages, salaries, & e...  123762.032754
# Compensation of employees; wages, salaries, & e...  982613.455520
# Operating surplus: Consumption of fixed capital     492193.505989
# Operating surplus: Remaining net operating surplus  470165.580176
#
#                                                     Post & telecommunications  \
# Unnamed: 1
# Taxes less subsidies on products purchased: Total                53017.654640
# Other net taxes on production                                    76330.835165
# Compensation of employees; wages, salaries, & e...              179387.895365
# Compensation of employees; wages, salaries, & e...               48842.343905
# Compensation of employees; wages, salaries, & e...              495731.758223
# Operating surplus: Consumption of fixed capital                 432617.967641
# Operating surplus: Remaining net operating surplus              329532.783852
#
#                                                     Financial intermediation & business activity  \
# Unnamed: 1
# Taxes less subsidies on products purchased: Total                                   3.604163e+05
# Other net taxes on production                                                       5.735303e+05
# Compensation of employees; wages, salaries, & e...                                  3.062913e+06
# Compensation of employees; wages, salaries, & e...                                  2.653186e+05
# Compensation of employees; wages, salaries, & e...                                  1.605018e+06
# Operating surplus: Consumption of fixed capital                                     2.657379e+06
# Operating surplus: Remaining net operating surplus                                  4.267086e+06
#
#                                                     Public administration; education; health; recreation; other services
# Unnamed: 1
# Taxes less subsidies on products purchased: Total                                        3.032797e+05
# Other net taxes on production                                                            1.153492e+05
# Compensation of employees; wages, salaries, & e...                                       4.876681e+06
# Compensation of employees; wages, salaries, & e...                                       3.792340e+05
# Compensation of employees; wages, salaries, & e...                                       2.452847e+06
# Operating surplus: Consumption of fixed capital                                          1.438234e+06
# Operating surplus: Remaining net operating surplus                                       8.425492e+05

# %%
x = np.array(Zdf.sum(axis=1) + Ydf.fillna(0).sum(axis=1))

# %%
A = np.array(Zdf) / x
S = np.array(Fdf) / x
V_bar = np.array(Vdf) / x
Y = np.array(Ydf)
L = np.linalg.inv(np.eye(17) - A)

# %% [markdown]
# **Preparation**
# What are the prices of the factors of production before the wage increase for low-skilled workers?
# What are the prices of commodities before the increase in wages for low-skilled workers?

# %% [markdown]
# **(a)** Define the price of factors of production, pi, after the increase in wages for low-skilled workers, assuming that there is no spillover to other groups.

# %%
pi=np.array([1,1,1,1.5,1,1,1])
# Out:
# array([1.02705664, 1.01893834, 1.02071539, 1.02048186, 1.01783335,
#        1.01579755, 1.01699074, 1.01741971, 1.01679987, 1.01726053,
#        1.01148797, 1.02877835, 1.02121951, 1.0208046 , 1.01552802,
#        1.01201681, 1.01740738])

# %% [markdown]
# **(b)** Calculate the price p of commodities after the wage rise for low-skilled workers. Display as a horizontal bar chart.

# %%
p = pi @ V_bar @ L
p

# %% [markdown]
# What are the two commodities that show the largest increase in prices? What does this tell us?
#
# Write here:

# %% [markdown]
# **(c)** Calculate the increase in the average cost of living for households.

# %%
CoLi = p @ Y[:,0] / sum(Y[:,0])

# %%
CoLi
# Out:
# 1.0171121331522464
