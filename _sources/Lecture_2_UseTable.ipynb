# %% [markdown]
# # Lecture 2 - Exploratory Data Analysis of the Use Table

# %% [markdown]
#
# Last week, we looked at the Supply Table for the US. Online, you find a Jupyter Notebook which imports the Supply Table, parses it (i.e., creates a variable that describes the part of the downloaded data that is of interest), and performs the sums to anser the questions. Please make sure you understand these operations.
#
# In the first part of the present exercise, we import the US Use Table and prepare it for subsequent analysis by separating out relevant, distinct parts (parsing). Then we do some exploratory data analysis to get to know the use table.
#
# Like the supply table, the published use table comes with various sums of columns and rows. We are only interested in the primary data; python can do summations and so we do not need to have the data summed. Further, the use table has  distinct blocks: <br>
#     - the use of commodities as intermediate input by industries,
#     - the use of factors of production (components of value added) by these industries, and
#     - the use of commodities by final demand, which includes final consumption by households, non-governmental institutions serving households, the government, as well as export, investment, and storage.
#     We identify those block and form the tables Use, Value Added, and FinalDemand. _Examine these tables and identify large flows_.<br><br>
#     <i>Q1: What is the sum total of each of those three matrices?</i><br>
#     <i>Q2: Determine and plot the total operating surplus of each industry sector.</i> What can we conclude from this? Why do you think it is called total operating surplus? What do costs do you think this surplus needs to cover? How is it different from profit?
#     _Q3: Plot the compensation of employees_. How does the sector distribution differ from that of the surplus?
# _Q4: Determine and plot the share of operating surplus in the value added in each sector._
#     _Q5: What industries are using agricultural products as intermediate inputs? Make a plot._
#     _Q6: Calculate the input coefficients (inputs per unit industry turnover). What commodities are used by all industries?_
#     _Q7: Compare the demand for commodities by industry with the final demand._ Which commodities are primarily used by industries? Which are predominantly used by final consumers?

# %%
# US Supply and Use Tables from url = "https://www.bea.gov/industry/input-output-accounts-data"

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

UseTable = pd.read_csv("U15_US_2021.csv", header=3, index_col=1, na_values='---').drop('Unnamed: 0', axis=1)   
        #You may have to add a path to the file name

# %%
UseTable
# Out:
#                                                     Agriculture, forestry, fishing, and hunting  \
# Name
# Agriculture, forestry, fishing, and hunting                                            131951.0
# Mining                                                                                   2295.0
# Utilities                                                                                5092.0
# Construction                                                                             1685.0
# Manufacturing                                                                          133667.0
# Wholesale trade                                                                          1396.0
# Retail trade                                                                                NaN
# Transportation and warehousing                                                            609.0
# Information                                                                               417.0
# Finance, insurance, real estate, rental, and le...                                      36405.0
# Professional and business services                                                       3769.0
# Educational services, health care, and social a...                                         18.0
# Arts, entertainment, recreation, accommodation,...                                        633.0
# Other services, except government                                                         709.0
# Government                                                                                 13.0
# Scrap, used and secondhand goods                                                           65.0
# Noncomparable imports and rest-of-the-world adj...                                        750.0
# Total Intermediate                                                                     319476.0
# Compensation of employees                                                               61364.0
# Other taxes on production                                                               12678.0
# Less: Other subsidies on production                                                      8930.0
# Gross operating surplus                                                                158612.0
# Value Added (basic prices)                                                             223724.0
# Total industry output (basic prices)                                                   543200.0
# Taxes on products and imports                                                             640.0
# Less: Subsidies on products                                                             17796.0
# Value Added (producer prices)                                                          206568.0
#
#                                                       Mining  Utilities  \
# Name
# Agriculture, forestry, fishing, and hunting            205.0        NaN
# Mining                                               82369.0    54149.0
# Utilities                                            10752.0    42391.0
# Construction                                          3236.0     8097.0
# Manufacturing                                        95986.0    46886.0
# Wholesale trade                                        195.0     1637.0
# Retail trade                                             NaN        NaN
# Transportation and warehousing                        2880.0    14597.0
# Information                                           1672.0     4516.0
# Finance, insurance, real estate, rental, and le...   37016.0    21787.0
# Professional and business services                   55639.0    49659.0
# Educational services, health care, and social a...       NaN      174.0
# Arts, entertainment, recreation, accommodation,...     532.0     4197.0
# Other services, except government                      749.0      755.0
# Government                                               3.0     4660.0
# Scrap, used and secondhand goods                      1914.0    10958.0
# Noncomparable imports and rest-of-the-world adj...    1428.0     1059.0
# Total Intermediate                                  294578.0   265522.0
# Compensation of employees                            67307.0    93294.0
# Other taxes on production                            32872.0    39202.0
# Less: Other subsidies on production                   3336.0      591.0
# Gross operating surplus                             222959.0   214790.0
# Value Added (basic prices)                          319802.0   346695.0
# Total industry output (basic prices)                614380.0   612217.0
# Taxes on products and imports                        14133.0    31741.0
# Less: Subsidies on products                              NaN        NaN
# Value Added (producer prices)                       333935.0   378436.0
#
#                                                     Construction  \
# Name
# Agriculture, forestry, fishing, and hunting               4938.0
# Mining                                                   33376.0
# Utilities                                                 7645.0
# Construction                                               275.0
# Manufacturing                                           733173.0
# Wholesale trade                                            114.0
# Retail trade                                                 NaN
# Transportation and warehousing                             699.0
# Information                                              10050.0
# Finance, insurance, real estate, rental, and le...       66010.0
# Professional and business services                      144341.0
# Educational services, health care, and social a...           5.0
# Arts, entertainment, recreation, accommodation,...        1305.0
# Other services, except government                        11492.0
# Government                                                   5.0
# Scrap, used and secondhand goods                          4059.0
# Noncomparable imports and rest-of-the-world adj...        1660.0
# Total Intermediate                                     1019148.0
# Compensation of employees                               635566.0
# Other taxes on production                                10699.0
# Less: Other subsidies on production                      34882.0
# Gross operating surplus                                 331437.0
# Value Added (basic prices)                              942821.0
# Total industry output (basic prices)                   1961969.0
# Taxes on products and imports                             2482.0
# Less: Subsidies on products                                  NaN
# Value Added (producer prices)                           945303.0
#
#                                                     Manufacturing  \
# Name
# Agriculture, forestry, fishing, and hunting              361145.0
# Mining                                                   414870.0
# Utilities                                                 57740.0
# Construction                                              12455.0
# Manufacturing                                           2379870.0
# Wholesale trade                                           25852.0
# Retail trade                                                  NaN
# Transportation and warehousing                            50890.0
# Information                                               20332.0
# Finance, insurance, real estate, rental, and le...        88826.0
# Professional and business services                       317990.0
# Educational services, health care, and social a...           51.0
# Arts, entertainment, recreation, accommodation,...         8334.0
# Other services, except government                         19925.0
# Government                                                 3177.0
# Scrap, used and secondhand goods                          43610.0
# Noncomparable imports and rest-of-the-world adj...        16854.0
# Total Intermediate                                      3821921.0
# Compensation of employees                               1183656.0
# Other taxes on production                                 68527.0
# Less: Other subsidies on production                       30937.0
# Gross operating surplus                                 1246756.0
# Value Added (basic prices)                              2468002.0
# Total industry output (basic prices)                    6289923.0
# Taxes on products and imports                             29177.0
# Less: Subsidies on products                                 374.0
# Value Added (producer prices)                           2496804.0
#
#                                                     Wholesale trade  \
# Name
# Agriculture, forestry, fishing, and hunting                  1905.0
# Mining                                                         62.0
# Utilities                                                   22971.0
# Construction                                                 2351.0
# Manufacturing                                              118487.0
# Wholesale trade                                             56193.0
# Retail trade                                                    NaN
# Transportation and warehousing                              97486.0
# Information                                                 27421.0
# Finance, insurance, real estate, rental, and le...         200270.0
# Professional and business services                         380924.0
# Educational services, health care, and social a...           1744.0
# Arts, entertainment, recreation, accommodation,...          12116.0
# Other services, except government                           40340.0
# Government                                                  13853.0
# Scrap, used and secondhand goods                                NaN
# Noncomparable imports and rest-of-the-world adj...           5267.0
# Total Intermediate                                         981391.0
# Compensation of employees                                  605994.0
# Other taxes on production                                   15335.0
# Less: Other subsidies on production                         11163.0
# Gross operating surplus                                    547472.0
# Value Added (basic prices)                                1157638.0
# Total industry output (basic prices)                      2139029.0
# Taxes on products and imports                              286859.0
# Less: Subsidies on products                                     NaN
# Value Added (producer prices)                             1444497.0
#
#                                                     Retail trade  \
# Name
# Agriculture, forestry, fishing, and hunting               4429.0
# Mining                                                      40.0
# Utilities                                                51091.0
# Construction                                              5398.0
# Manufacturing                                           116511.0
# Wholesale trade                                          30802.0
# Retail trade                                              3994.0
# Transportation and warehousing                          104559.0
# Information                                              34166.0
# Finance, insurance, real estate, rental, and le...      252550.0
# Professional and business services                      311053.0
# Educational services, health care, and social a...        7398.0
# Arts, entertainment, recreation, accommodation,...       13992.0
# Other services, except government                        26872.0
# Government                                                7417.0
# Scrap, used and secondhand goods                           486.0
# Noncomparable imports and rest-of-the-world adj...        4473.0
# Total Intermediate                                      975231.0
# Compensation of employees                               745483.0
# Other taxes on production                                26430.0
# Less: Other subsidies on production                      23078.0
# Gross operating surplus                                 373931.0
# Value Added (basic prices)                             1122766.0
# Total industry output (basic prices)                   2097998.0
# Taxes on products and imports                           268361.0
# Less: Subsidies on products                                  NaN
# Value Added (producer prices)                          1391128.0
#
#                                                     Transportation and warehousing  \
# Name
# Agriculture, forestry, fishing, and hunting                                  165.0
# Mining                                                                       247.0
# Utilities                                                                  20610.0
# Construction                                                                7194.0
# Manufacturing                                                             163025.0
# Wholesale trade                                                              316.0
# Retail trade                                                                   NaN
# Transportation and warehousing                                            189688.0
# Information                                                                19435.0
# Finance, insurance, real estate, rental, and le...                        144168.0
# Professional and business services                                        142202.0
# Educational services, health care, and social a...                           258.0
# Arts, entertainment, recreation, accommodation,...                         25151.0
# Other services, except government                                          21279.0
# Government                                                                 15201.0
# Scrap, used and secondhand goods                                           -1978.0
# Noncomparable imports and rest-of-the-world adj...                         20371.0
# Total Intermediate                                                        767332.0
# Compensation of employees                                                 457113.0
# Other taxes on production                                                  20719.0
# Less: Other subsidies on production                                        32508.0
# Gross operating surplus                                                   227885.0
# Value Added (basic prices)                                                673210.0
# Total industry output (basic prices)                                     1440542.0
# Taxes on products and imports                                              20434.0
# Less: Subsidies on products                                                 5407.0
# Value Added (producer prices)                                             688237.0
#
#                                                     Information  \
# Name
# Agriculture, forestry, fishing, and hunting                 NaN
# Mining                                                   1733.0
# Utilities                                                7365.0
# Construction                                             2747.0
# Manufacturing                                          120872.0
# Wholesale trade                                          3050.0
# Retail trade                                                NaN
# Transportation and warehousing                          20779.0
# Information                                            263770.0
# Finance, insurance, real estate, rental, and le...     104937.0
# Professional and business services                     354437.0
# Educational services, health care, and social a...        245.0
# Arts, entertainment, recreation, accommodation,...      36688.0
# Other services, except government                       11817.0
# Government                                               2923.0
# Scrap, used and secondhand goods                            1.0
# Noncomparable imports and rest-of-the-world adj...       8802.0
# Total Intermediate                                     940166.0
# Compensation of employees                              507857.0
# Other taxes on production                               18735.0
# Less: Other subsidies on production                      7092.0
# Gross operating surplus                                748600.0
# Value Added (basic prices)                            1268099.0
# Total industry output (basic prices)                  2208265.0
# Taxes on products and imports                           45157.0
# Less: Subsidies on products                                 0.0
# Value Added (producer prices)                         1313256.0
#
#                                                     Finance, insurance, real estate, rental, and leasing  \
# Name
# Agriculture, forestry, fishing, and hunting                                                       7.0
# Mining                                                                                          622.0
# Utilities                                                                                    149311.0
# Construction                                                                                 184213.0
# Manufacturing                                                                                116028.0
# Wholesale trade                                                                               11346.0
# Retail trade                                                                                      NaN
# Transportation and warehousing                                                                24431.0
# Information                                                                                   63981.0
# Finance, insurance, real estate, rental, and le...                                          1535980.0
# Professional and business services                                                           653943.0
# Educational services, health care, and social a...                                               67.0
# Arts, entertainment, recreation, accommodation,...                                            89926.0
# Other services, except government                                                             38944.0
# Government                                                                                    17777.0
# Scrap, used and secondhand goods                                                                -44.0
# Noncomparable imports and rest-of-the-world adj...                                            51946.0
# Total Intermediate                                                                          2938478.0
# Compensation of employees                                                                   1179563.0
# Other taxes on production                                                                    382081.0
# Less: Other subsidies on production                                                           10813.0
# Gross operating surplus                                                                     3314056.0
# Value Added (basic prices)                                                                  4864887.0
# Total industry output (basic prices)                                                        7803365.0
# Taxes on products and imports                                                                 52561.0
# Less: Subsidies on products                                                                   31800.0
# Value Added (producer prices)                                                               4885647.0
#
#                                                     ...  \
# Name                                                ...
# Agriculture, forestry, fishing, and hunting         ...
# Mining                                              ...
# Utilities                                           ...
# Construction                                        ...
# Manufacturing                                       ...
# Wholesale trade                                     ...
# Retail trade                                        ...
# Transportation and warehousing                      ...
# Information                                         ...
# Finance, insurance, real estate, rental, and le...  ...
# Professional and business services                  ...
# Educational services, health care, and social a...  ...
# Arts, entertainment, recreation, accommodation,...  ...
# Other services, except government                   ...
# Government                                          ...
# Scrap, used and secondhand goods                    ...
# Noncomparable imports and rest-of-the-world adj...  ...
# Total Intermediate                                  ...
# Compensation of employees                           ...
# Other taxes on production                           ...
# Less: Other subsidies on production                 ...
# Gross operating surplus                             ...
# Value Added (basic prices)                          ...
# Total industry output (basic prices)                ...
# Taxes on products and imports                       ...
# Less: Subsidies on products                         ...
# Value Added (producer prices)                       ...
#
#                                                     Arts, entertainment, recreation, accommodation, and food services  \
# Name
# Agriculture, forestry, fishing, and hunting                                                   13510.0
# Mining                                                                                         1461.0
# Utilities                                                                                     38791.0
# Construction                                                                                   2992.0
# Manufacturing                                                                                174626.0
# Wholesale trade                                                                                 169.0
# Retail trade                                                                                      NaN
# Transportation and warehousing                                                                 8437.0
# Information                                                                                   24481.0
# Finance, insurance, real estate, rental, and le...                                           154848.0
# Professional and business services                                                           224322.0
# Educational services, health care, and social a...                                             5154.0
# Arts, entertainment, recreation, accommodation,...                                            45168.0
# Other services, except government                                                             21393.0
# Government                                                                                     6101.0
# Scrap, used and secondhand goods                                                                918.0
# Noncomparable imports and rest-of-the-world adj...                                             3357.0
# Total Intermediate                                                                           725729.0
# Compensation of employees                                                                    538307.0
# Other taxes on production                                                                     19831.0
# Less: Other subsidies on production                                                           95947.0
# Gross operating surplus                                                                      338892.0
# Value Added (basic prices)                                                                   801083.0
# Total industry output (basic prices)                                                        1526812.0
# Taxes on products and imports                                                                104389.0
# Less: Subsidies on products                                                                       NaN
# Value Added (producer prices)                                                                905472.0
#
#                                                     Other services, except government  \
# Name
# Agriculture, forestry, fishing, and hunting                                     305.0
# Mining                                                                          932.0
# Utilities                                                                      4022.0
# Construction                                                                   3689.0
# Manufacturing                                                                 72546.0
# Wholesale trade                                                                  40.0
# Retail trade                                                                     19.0
# Transportation and warehousing                                                 5084.0
# Information                                                                   17129.0
# Finance, insurance, real estate, rental, and le...                            84218.0
# Professional and business services                                            64446.0
# Educational services, health care, and social a...                             7132.0
# Arts, entertainment, recreation, accommodation,...                             9689.0
# Other services, except government                                              9389.0
# Government                                                                     2076.0
# Scrap, used and secondhand goods                                               5089.0
# Noncomparable imports and rest-of-the-world adj...                              388.0
# Total Intermediate                                                           286194.0
# Compensation of employees                                                    350173.0
# Other taxes on production                                                     12331.0
# Less: Other subsidies on production                                           19574.0
# Gross operating surplus                                                      110589.0
# Value Added (basic prices)                                                   453519.0
# Total industry output (basic prices)                                         739712.0
# Taxes on products and imports                                                 16333.0
# Less: Subsidies on products                                                       NaN
# Value Added (producer prices)                                                469851.0
#
#                                                     Government  \
# Name
# Agriculture, forestry, fishing, and hunting             8934.0
# Mining                                                 35971.0
# Utilities                                              38179.0
# Construction                                          106772.0
# Manufacturing                                         582477.0
# Wholesale trade                                           42.0
# Retail trade                                               NaN
# Transportation and warehousing                         40103.0
# Information                                           112175.0
# Finance, insurance, real estate, rental, and le...    251270.0
# Professional and business services                    329399.0
# Educational services, health care, and social a...     48681.0
# Arts, entertainment, recreation, accommodation,...     26171.0
# Other services, except government                      53067.0
# Government                                              9917.0
# Scrap, used and secondhand goods                          -9.0
# Noncomparable imports and rest-of-the-world adj...     11553.0
# Total Intermediate                                   1654702.0
# Compensation of employees                            2210905.0
# Other taxes on production                                  NaN
# Less: Other subsidies on production                        NaN
# Gross operating surplus                               649144.0
# Value Added (basic prices)                           2860049.0
# Total industry output (basic prices)                 4514751.0
# Taxes on products and imports                            639.0
# Less: Subsidies on products                            47807.0
# Value Added (producer prices)                        2812880.0
#
#                                                     Total Intermediate  \
# Name
# Agriculture, forestry, fishing, and hunting                     530936
# Mining                                                          631676
# Utilities                                                       499094
# Construction                                                    344569
# Manufacturing                                                  5400196
# Wholesale trade                                                 132127
# Retail trade                                                      4012
# Transportation and warehousing                                  639850
# Information                                                     797565
# Finance, insurance, real estate, rental, and le...             3667844
# Professional and business services                             4250451
# Educational services, health care, and social a...              121634
# Arts, entertainment, recreation, accommodation,...              437460
# Other services, except government                               329784
# Government                                                      101286
# Scrap, used and secondhand goods                                 66761
# Noncomparable imports and rest-of-the-world adj...              134438
# Total Intermediate                                            18089683
# Compensation of employees                                     12549140
# Other taxes on production                                       730987
# Less: Other subsidies on production                             378750
# Gross operating surplus                                        9584486
# Value Added (basic prices)                                    22485863
# Total industry output (basic prices)                          40575547
# Taxes on products and imports                                   932411
# Less: Subsidies on products                                     103194
# Value Added (producer prices)                                 23315081
#
#                                                     Personal consumption expenditures  \
# Name
# Agriculture, forestry, fishing, and hunting                                  206441.0
# Mining                                                                           61.0
# Utilities                                                                    306712.0
# Construction                                                                      NaN
# Manufacturing                                                               4680651.0
# Wholesale trade                                                                   NaN
# Retail trade                                                                  10275.0
# Transportation and warehousing                                               214082.0
# Information                                                                  706747.0
# Finance, insurance, real estate, rental, and le...                          3811539.0
# Professional and business services                                           305821.0
# Educational services, health care, and social a...                          3345318.0
# Arts, entertainment, recreation, accommodation,...                          1318316.0
# Other services, except government                                            631191.0
# Government                                                                    83445.0
# Scrap, used and secondhand goods                                             288607.0
# Noncomparable imports and rest-of-the-world adj...                            -6631.0
# Total Intermediate                                                         15902575.0
# Compensation of employees                                                         NaN
# Other taxes on production                                                         NaN
# Less: Other subsidies on production                                               NaN
# Gross operating surplus                                                           NaN
# Value Added (basic prices)                                                        NaN
# Total industry output (basic prices)                                              NaN
# Taxes on products and imports                                                     NaN
# Less: Subsidies on products                                                       NaN
# Value Added (producer prices)                                                     NaN
#
#                                                     Private fixed investment  \
# Name
# Agriculture, forestry, fishing, and hunting                              NaN
# Mining                                                               79979.0
# Utilities                                                                NaN
# Construction                                                       1339778.0
# Manufacturing                                                      1297203.0
# Wholesale trade                                                          NaN
# Retail trade                                                             NaN
# Transportation and warehousing                                           NaN
# Information                                                         319225.0
# Finance, insurance, real estate, rental, and le...                  205411.0
# Professional and business services                                 1024058.0
# Educational services, health care, and social a...                       NaN
# Arts, entertainment, recreation, accommodation,...                    6284.0
# Other services, except government                                        NaN
# Government                                                               NaN
# Scrap, used and secondhand goods                                   -156030.0
# Noncomparable imports and rest-of-the-world adj...                   16684.0
# Total Intermediate                                                 4132592.0
# Compensation of employees                                                NaN
# Other taxes on production                                                NaN
# Less: Other subsidies on production                                      NaN
# Gross operating surplus                                                  NaN
# Value Added (basic prices)                                               NaN
# Total industry output (basic prices)                                     NaN
# Taxes on products and imports                                            NaN
# Less: Subsidies on products                                              NaN
# Value Added (producer prices)                                            NaN
#
#                                                     Change in private inventories  \
# Name
# Agriculture, forestry, fishing, and hunting                               -6895.0
# Mining                                                                      439.0
# Utilities                                                                     NaN
# Construction                                                                  NaN
# Manufacturing                                                             -6454.0
# Wholesale trade                                                               NaN
# Retail trade                                                                  NaN
# Transportation and warehousing                                                NaN
# Information                                                                7200.0
# Finance, insurance, real estate, rental, and le...                            NaN
# Professional and business services                                            NaN
# Educational services, health care, and social a...                            NaN
# Arts, entertainment, recreation, accommodation,...                            NaN
# Other services, except government                                             NaN
# Government                                                                    NaN
# Scrap, used and secondhand goods                                         -13381.0
# Noncomparable imports and rest-of-the-world adj...                            NaN
# Total Intermediate                                                       -19091.0
# Compensation of employees                                                     NaN
# Other taxes on production                                                     NaN
# Less: Other subsidies on production                                           NaN
# Gross operating surplus                                                       NaN
# Value Added (basic prices)                                                    NaN
# Total industry output (basic prices)                                          NaN
# Taxes on products and imports                                                 NaN
# Less: Subsidies on products                                                   NaN
# Value Added (producer prices)                                                 NaN
#
#                                                     Exports of goods and services  \
# Name
# Agriculture, forestry, fishing, and hunting                               84924.0
# Mining                                                                   127875.0
# Utilities                                                                  3573.0
# Construction                                                                115.0
# Manufacturing                                                           1135707.0
# Wholesale trade                                                            2805.0
# Retail trade                                                                  NaN
# Transportation and warehousing                                            44254.0
# Information                                                               77011.0
# Finance, insurance, real estate, rental, and le...                       285042.0
# Professional and business services                                       270431.0
# Educational services, health care, and social a...                        14077.0
# Arts, entertainment, recreation, accommodation,...                         3200.0
# Other services, except government                                            93.0
# Government                                                                  874.0
# Scrap, used and secondhand goods                                          51762.0
# Noncomparable imports and rest-of-the-world adj...                        77670.0
# Total Intermediate                                                      2179415.0
# Compensation of employees                                                     NaN
# Other taxes on production                                                     NaN
# Less: Other subsidies on production                                           NaN
# Gross operating surplus                                                       NaN
# Value Added (basic prices)                                                    NaN
# Total industry output (basic prices)                                          NaN
# Taxes on products and imports                                                 NaN
# Less: Subsidies on products                                                   NaN
# Value Added (producer prices)                                                 NaN
#
#                                                     Government consumption expenditures and gross investment  \
# Name
# Agriculture, forestry, fishing, and hunting                                                       NaN
# Mining                                                                                            NaN
# Utilities                                                                                         NaN
# Construction                                                                                 367192.0
# Manufacturing                                                                                148409.0
# Wholesale trade                                                                                   NaN
# Retail trade                                                                                      NaN
# Transportation and warehousing                                                                    NaN
# Information                                                                                   20990.0
# Finance, insurance, real estate, rental, and le...                                                NaN
# Professional and business services                                                           245445.0
# Educational services, health care, and social a...                                                NaN
# Arts, entertainment, recreation, accommodation,...                                                NaN
# Other services, except government                                                                 NaN
# Government                                                                                  3353731.0
# Scrap, used and secondhand goods                                                              24950.0
# Noncomparable imports and rest-of-the-world adj...                                                NaN
# Total Intermediate                                                                          4160717.0
# Compensation of employees                                                                         NaN
# Other taxes on production                                                                         NaN
# Less: Other subsidies on production                                                               NaN
# Gross operating surplus                                                                           NaN
# Value Added (basic prices)                                                                        NaN
# Total industry output (basic prices)                                                              NaN
# Taxes on products and imports                                                                     NaN
# Less: Subsidies on products                                                                       NaN
# Value Added (producer prices)                                                                     NaN
#
#                                                     Total use of products
# Name
# Agriculture, forestry, fishing, and hunting                      815406.0
# Mining                                                           840031.0
# Utilities                                                        809379.0
# Construction                                                    2051653.0
# Manufacturing                                                  12655713.0
# Wholesale trade                                                  134933.0
# Retail trade                                                      14288.0
# Transportation and warehousing                                   898185.0
# Information                                                     1928738.0
# Finance, insurance, real estate, rental, and le...              7965548.0
# Professional and business services                              6100496.0
# Educational services, health care, and social a...              3481029.0
# Arts, entertainment, recreation, accommodation,...              1765260.0
# Other services, except government                                961068.0
# Government                                                      3539336.0
# Scrap, used and secondhand goods                                 262669.0
# Noncomparable imports and rest-of-the-world adj...               222160.0
# Total Intermediate                                             44445892.0
# Compensation of employees                                             NaN
# Other taxes on production                                             NaN
# Less: Other subsidies on production                                   NaN
# Gross operating surplus                                               NaN
# Value Added (basic prices)                                            NaN
# Total industry output (basic prices)                                  NaN
# Taxes on products and imports                                         NaN
# Less: Subsidies on products                                           NaN
# Value Added (producer prices)                                         NaN
#
# [27 rows x 22 columns]

# %% [markdown]
# Examine the sections of the table by checking the row and column names. If this does not show well on your PC, do so in the Excel version of the table. (PS: Please note that the drop command below just serves to delete the column of sector numbers).

# %% [markdown]
# Define the intermediate use (by industries) of commodites. The second line defines the number of digit after the comma. fillna(0) replaced Nan by zero. The last command formats the background of the table in colors depending on the size of the value. Please examine these tables.

# %%
Use=UseTable.iloc[0:16,1:15]             #Use of commodities by industries
pd.set_option('display.precision', 0)
Use.fillna(0).style.background_gradient(cmap ='Blues')
# Out:
# <style type="text/css">
# #T_316e4_row0_col0, #T_316e4_row0_col1, #T_316e4_row0_col7, #T_316e4_row0_col8, #T_316e4_row0_col9, #T_316e4_row0_col10, #T_316e4_row0_col12, #T_316e4_row1_col4, #T_316e4_row1_col5, #T_316e4_row1_col8, #T_316e4_row1_col9, #T_316e4_row1_col10, #T_316e4_row3_col2, #T_316e4_row3_col9, #T_316e4_row5_col0, #T_316e4_row5_col2, #T_316e4_row5_col9, #T_316e4_row5_col10, #T_316e4_row5_col11, #T_316e4_row5_col12, #T_316e4_row5_col13, #T_316e4_row6_col0, #T_316e4_row6_col1, #T_316e4_row6_col2, #T_316e4_row6_col3, #T_316e4_row6_col4, #T_316e4_row6_col7, #T_316e4_row6_col8, #T_316e4_row6_col9, #T_316e4_row6_col10, #T_316e4_row6_col11, #T_316e4_row6_col12, #T_316e4_row6_col13, #T_316e4_row7_col2, #T_316e4_row11_col0, #T_316e4_row11_col1, #T_316e4_row11_col2, #T_316e4_row11_col3, #T_316e4_row11_col7, #T_316e4_row11_col8, #T_316e4_row11_col9, #T_316e4_row12_col2, #T_316e4_row12_col3, #T_316e4_row14_col0, #T_316e4_row14_col2, #T_316e4_row14_col3, #T_316e4_row15_col4, #T_316e4_row15_col5, #T_316e4_row15_col6, #T_316e4_row15_col7, #T_316e4_row15_col8, #T_316e4_row15_col9, #T_316e4_row15_col10, #T_316e4_row15_col13 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_316e4_row0_col2, #T_316e4_row0_col4, #T_316e4_row1_col7, #T_316e4_row1_col11, #T_316e4_row3_col3, #T_316e4_row3_col4, #T_316e4_row3_col7, #T_316e4_row3_col10, #T_316e4_row5_col8, #T_316e4_row11_col4, #T_316e4_row12_col0, #T_316e4_row13_col0, #T_316e4_row15_col2, #T_316e4_row15_col11 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_316e4_row0_col3, #T_316e4_row3_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_316e4_row0_col5, #T_316e4_row0_col13, #T_316e4_row3_col11, #T_316e4_row5_col6, #T_316e4_row6_col5, #T_316e4_row8_col2, #T_316e4_row13_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_316e4_row0_col6, #T_316e4_row1_col6, #T_316e4_row1_col12, #T_316e4_row2_col2, #T_316e4_row5_col3, #T_316e4_row5_col7, #T_316e4_row6_col6, #T_316e4_row8_col3, #T_316e4_row11_col6, #T_316e4_row13_col3, #T_316e4_row14_col7, #T_316e4_row14_col8, #T_316e4_row14_col9 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_316e4_row0_col11, #T_316e4_row1_col13, #T_316e4_row2_col4, #T_316e4_row2_col10, #T_316e4_row7_col7, #T_316e4_row7_col12, #T_316e4_row15_col12 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_316e4_row1_col0 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_316e4_row1_col1, #T_316e4_row4_col0, #T_316e4_row4_col2, #T_316e4_row4_col3, #T_316e4_row4_col13, #T_316e4_row7_col6, #T_316e4_row9_col8, #T_316e4_row9_col10, #T_316e4_row9_col12, #T_316e4_row10_col4, #T_316e4_row10_col5, #T_316e4_row10_col7, #T_316e4_row10_col9, #T_316e4_row10_col11 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_316e4_row1_col2, #T_316e4_row2_col12, #T_316e4_row3_col6, #T_316e4_row3_col12, #T_316e4_row12_col5, #T_316e4_row12_col13, #T_316e4_row13_col9 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_316e4_row1_col3, #T_316e4_row2_col11, #T_316e4_row8_col9 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_316e4_row2_col0, #T_316e4_row8_col5, #T_316e4_row8_col6, #T_316e4_row12_col9, #T_316e4_row13_col12 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_316e4_row2_col1 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_316e4_row2_col3, #T_316e4_row2_col9, #T_316e4_row11_col5, #T_316e4_row13_col8, #T_316e4_row14_col5, #T_316e4_row14_col10, #T_316e4_row14_col11, #T_316e4_row14_col12 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_316e4_row2_col5 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_316e4_row2_col6, #T_316e4_row3_col8 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_316e4_row2_col7, #T_316e4_row7_col3, #T_316e4_row11_col11, #T_316e4_row15_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_316e4_row2_col8, #T_316e4_row13_col11 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_316e4_row2_col13 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_316e4_row3_col0, #T_316e4_row12_col4, #T_316e4_row13_col7 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_316e4_row3_col5, #T_316e4_row7_col8, #T_316e4_row8_col0, #T_316e4_row13_col2, #T_316e4_row14_col13, #T_316e4_row15_col3 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_316e4_row3_col13 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_316e4_row4_col1 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_316e4_row4_col4 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_316e4_row4_col5 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_316e4_row4_col6, #T_316e4_row4_col12 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_316e4_row4_col7 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_316e4_row4_col8, #T_316e4_row12_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_316e4_row4_col9 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_316e4_row4_col10 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_316e4_row4_col11 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_316e4_row5_col1, #T_316e4_row7_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_316e4_row5_col4 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_316e4_row5_col5 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_316e4_row7_col1 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_316e4_row7_col4 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_316e4_row7_col5 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_316e4_row7_col9, #T_316e4_row7_col13 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_316e4_row7_col10 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_316e4_row7_col11, #T_316e4_row9_col3, #T_316e4_row14_col4 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_316e4_row8_col1, #T_316e4_row11_col12, #T_316e4_row11_col13 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_316e4_row8_col4 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_316e4_row8_col7 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_316e4_row8_col8 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_316e4_row8_col10, #T_316e4_row10_col3 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_316e4_row8_col11, #T_316e4_row13_col4 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_316e4_row8_col12 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_316e4_row8_col13 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_316e4_row9_col0 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_316e4_row9_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_316e4_row9_col2, #T_316e4_row13_col10, #T_316e4_row13_col13 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_316e4_row9_col4 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_316e4_row9_col5 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_316e4_row9_col6, #T_316e4_row10_col12 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_316e4_row9_col7 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_316e4_row9_col9 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_316e4_row9_col11 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_316e4_row9_col13 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_316e4_row10_col0 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_316e4_row10_col1 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_316e4_row10_col2 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_316e4_row10_col6 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_316e4_row10_col8 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_316e4_row10_col10 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_316e4_row10_col13 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_316e4_row11_col10, #T_316e4_row12_col6 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_316e4_row12_col7 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_316e4_row12_col8 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_316e4_row12_col10 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_316e4_row12_col11, #T_316e4_row15_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_3

# %%
ValueAdded=UseTable.iloc[18:21,1:15]                     #Use of Factors of Production by industry
ValueAdded.style.background_gradient(cmap ='Blues')
# Out:
# <style type="text/css">
# #T_4ebce_row0_col0, #T_4ebce_row0_col1, #T_4ebce_row0_col2, #T_4ebce_row0_col3, #T_4ebce_row0_col4, #T_4ebce_row0_col5, #T_4ebce_row0_col6, #T_4ebce_row0_col7, #T_4ebce_row0_col8, #T_4ebce_row0_col9, #T_4ebce_row0_col10, #T_4ebce_row0_col11, #T_4ebce_row0_col12 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4ebce_row0_col13, #T_4ebce_row1_col2, #T_4ebce_row1_col6, #T_4ebce_row1_col9, #T_4ebce_row1_col10, #T_4ebce_row1_col11, #T_4ebce_row1_col12, #T_4ebce_row1_col13, #T_4ebce_row2_col0, #T_4ebce_row2_col1, #T_4ebce_row2_col3, #T_4ebce_row2_col4, #T_4ebce_row2_col5, #T_4ebce_row2_col7, #T_4ebce_row2_col8, #T_4ebce_row2_col13 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_4ebce_row1_col0 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_4ebce_row1_col1 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_4ebce_row1_col3 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_4ebce_row1_col4, #T_4ebce_row1_col5, #T_4ebce_row2_col9 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_4ebce_row1_col7, #T_4ebce_row2_col12 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_4ebce_row1_col8 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_4ebce_row2_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_4ebce_row2_col6 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_4ebce_row2_col10 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_4ebce_row2_col11 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# </style>
# <table id="T_4ebce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ebce_level0_col0" class="col_heading level0 col0" >Mining</th>
#       <th id="T_4ebce_level0_col1" class="col_heading level0 col1" >Utilities</th>
#       <th id="T_4ebce_level0_col2" class="col_heading level0 col2" >Construction</th>
#       <th id="T_4ebce_level0_col3" class="col_heading level0 col3" >Manufacturing</th>
#       <th id="T_4ebce_level0_col4" class="col_heading level0 col4" >Wholesale trade</th>
#       <th id="T_4ebce_level0_col5" class="col_heading level0 col5" >Retail trade</th>
#       <th id="T_4ebce_level0_col6" class="col_heading level0 col6" >Transportation and warehousing</th>
#       <th id="T_4ebce_level0_col7" class="col_heading level0 col7" >Information</th>
#       <th id="T_4ebce_level0_col8" class="col_heading level0 col8" >Finance, insurance, real estate, rental, and leasing</th>
#       <th id="T_4ebce_level0_col9" class="col_heading level0 col9" >Professional and business services</th>
#       <th id="T_4ebce_level0_col10" class="col_heading level0 col10" >Educational services, health care, and social assistance</th>
#       <th id="T_4ebce_level0_col11" class="col_heading level0 col11" >Arts, entertainment, recreation, accommodation, and food services</th>
#       <th id="T_4ebce_level0_col12" class="col_heading level0 col12" >Other services, except government</th>
#       <th id="T_4ebce_level0_col13" class="col_heading level0 col13" >Government</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ebce_level0_row0" class="row_heading level0 row0" >Compensation of employees</th>
#       <td id="T_4ebce_row0_col0" class="data row0 col0" >67307.000000</td>
#       <td id="T_4ebce_row0_col1" class="data row0 col1" >93294.000000</td>
#       <td id="T_4ebce_row0_col2" class="data row0 col2" >635566.000000</td>
#       <td id="T_4ebce_row0_col3" class="data row0 col3" >1183656.000000</td>
#       <td id="T_4ebce_row0_col4" class="data row0 col4" >605994.000000</td>
#       <td id="T_4ebce_row0_col5" class="data row0 col5" >745483.000000</td>
#       <td id="T_4ebce_row0_col6" class="data row0 col6" >457113.000000</td>
#       <td id="T_4ebce_row0_col7" class="data row0 col7" >507857.000000</td>
#       <td id="T_4ebce_row0_col8" class="data row0 col8" >1179563.000000</td>
#       <td id="T_4ebce_row0_col9" class="data row0 col9" >2242330.000000</td>
#       <td id="T_4ebce_row0_col10" class="data row0 col10" >1670227.000000</td>
#       <td id="T_4ebce_row0_col11" class="data row0 col11" >538307.000000</td>
#       <td id="T_4ebce_row0_col12" class="data row0 col12" >350173.000000</td>
#       <td id="T_4ebce_row0_col13" class="data row0 col13" >2210905.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4ebce_level0_row1" class="row_heading level0 row1" >Other taxes on production</th>
#       <td id="T_4ebce_row1_col0" class="data row1 col0" >32872.000000</td>
#       <td id="T_4ebce_row1_col1" class="data row1 col1" >39202.000000</td>
#       <td id="T_4ebce_row1_col2" class="data row1 col2" >10699.000000</td>
#       <td id="T_4ebce_row1_col3" class="data row1 col3" >68527.000000</td>
#       <td id="T_4ebce_row1_col4" class="data row1 col4" >15335.000000</td>
#       <td id="T_4ebce_row1_col5" class="data row1 col5" >26430.000000</td>
#       <td id="T_4ebce_row1_col6" class="data row1 col6" >20719.000000</td>
#       <td id="T_4ebce_row1_col7" class="data row1 col7" >18735.000000</td>
#       <td id="T_4ebce_row1_col8" class="data row1 col8" >382081.000000</td>
#       <td id="T_4ebce_row1_col9" class="data row1 col9" >32266.000000</td>
#       <td id="T_4ebce_row1_col10" class="data row1 col10" >39281.000000</td>
#       <td id="T_4ebce_row1_col11" class="data row1 col11" >19831.000000</td>
#       <td id="T_4ebce_row1_col12" class="data row1 col12" >12331.000000</td>
#       <td id="T_4ebce_row1_col13" class="data row1 col13" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_4ebce_level0_row2" class="row_heading level0 row2" >Less: Other subsidies on production</th>
#       <td id="T_4ebce_row2_col0" class="data row2 col0" >3336.000000</td>
#       <td id="T_4ebce_row2_col1" class="data row2 col1" >591.000000</td>
#       <td id="T_4ebce_row2_col2" class="data row2 col2" >34882.000000</td>
#       <td id="T_4ebce_row2_col3" class="data row2 col3" >30937.000000</td>
#       <td id="T_4ebce_row2_col4" class="data row2 col4" >11163.000000</td>
#       <td id="T_4ebce_row2_col5" class="data row2 col5" >23078.000000</td>
#       <td id="T_4ebce_row2_col6" class="data row2 col6" >32508.000000</td>
#       <td id="T_4ebce_row2_col7" class="data row2 col7" >7092.000000</td>
#       <td id="T_4ebce_row2_col8" class="data row2 col8" >10813.000000</td>
#       <td id="T_4ebce_row2_col9" class="data row2 col9" >41156.000000</td>
#       <td id="T_4ebce_row2_col10" class="data row2 col10" >58742.000000</td>
#       <td id="T_4ebce_row2_col11" class="data row2 col11" >95947.000000</td>
#       <td id="T_4ebce_row2_col12" class="data row2 col12" >19574.000000</td>
#       <td id="T_4ebce_row2_col13" class="data row2 col13" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
FinalDemand=UseTable.iloc[0:16,17:22]
#Have a look at the table. Identify the largest final demand category for each commodity. (Just note, no need to report.)

# %% [markdown]
# **Q1: What is the sum total of those three matrices?**
# Please also print out the total volume of value added and final demand. The Use table is in million US dollars.

# %%
Use_Total = Use.sum().sum()

print('Total use of commodities by industries:', Use_Total/1000000, ' trillion dollars')
# print the sums in trillions for the two other matrices. Why did we have to sum twice?

# %%
#How do you like this figure? Why do we need to sum only once? What happens if we write (axis=1) after sum?
ValueAdded.sum().plot(kind='pie')

# %% [markdown]
# **Q2: Determine and plot the total operating surplus of each industry sector.**

# %%
(ValueAdded/1000).loc['Gross operating surplus'].plot(kind='hbar',xlabel='Surplus in billion $')

# %% [markdown]
# **Q3: Determine and plot the compensation of employees.**

# %% [markdown]
# **Q4: Determine and plot the share of operating surplus in the value added in each sector.**

# %%
SurplusShareVA=ValueAdded.loc['Gross operating surplus']/ValueAdded.sum()
SurplusShareVA.plot(kind='bar', ylabel="Surplus per unit Value Added")

# %% [markdown]
# **Q5: What industries are using agricultural products as intermediate inputs? Make a plot.**

# %% [markdown]
# **Q6: Calculate the input coefficients (inputs per unit industry turnover).** What commodities are used by all industries?

# %%
IndustryTotalInput = Use.sum() + ValueAdded.sum()
IndustryTotalInput.plot(kind='pie')

# %%
##Fill in here:
Use_coefficient # = ...
pd.set_option('display.precision', 2)
Use_coefficient.fillna(0).style.background_gradient(cmap ='Blues')

# %%
print('Following commodities are used by all industries: (fill in here)')

# %% [markdown]
# **Q7: Compare the demand for commodities by industry with the final demand.**
# Which commodities are primarily used by industries? Which are predominantly used by final consumers?

# %%
df1=pd.DataFrame(data=Use.sum(axis=1), columns=['Intermediate'])
df2=pd.DataFrame(data=FinalDemand.sum(axis=1), columns=['Final'])
CommodityDemand=df1.merge(df2, on='Name')
(CommodityDemand/1000000).plot(kind='bar',stacked=True, ylabel='Commodity demand trillion $')

# %%
CommodityDemand.sum().plot(kind='pie')

# %%
CommodityDemand.plot(kind='scatter', x='Intermediate', y='Final')

# %% [markdown]
# Write your interpretation of the results in Q7 here:
